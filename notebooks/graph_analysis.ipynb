# %%
import pandas as pd

# %%
entity_data = pd.read_parquet('../datasets/graphs/obliqa-full/output/entities.parquet')

# %%
entity_data.head()
# Out:
#                                      id  human_readable_id  \
# 0  3eb72b30-b3b1-4540-80d6-a6f5b2ddb7dd                  0
# 1  7efe0e99-052e-4da1-ba10-fceca9b2dbbe                  1
# 2  60d0a962-987e-4003-a7b9-2cbddc875733                  2
# 3  7f3bc78f-4738-45d8-a12a-beea94fedddd                  3
# 4  9ecbb1c0-b3a5-46fa-b9c1-938ca39d499c                  4
#
#                                             title          type  \
# 0  FINANCIAL SERVICES REGULATORY AUTHORITY (FSRA)  ORGANIZATION
# 1                  ABU DHABI GLOBAL MARKET (ADGM)           GEO
# 2                     VIRTUAL ASSET (VA) INDUSTRY  ORGANIZATION
# 3                                  DIGITAL ASSETS  ORGANIZATION
# 4                              DIGITAL SECURITIES  ORGANIZATION
#
#                                          description  \
# 0  The Financial Services Regulatory Authority (F...
# 1  ABU DHABI GLOBAL MARKET (ADGM) is a financial ...
# 2  The VA industry is a sector that includes vari...
# ...
